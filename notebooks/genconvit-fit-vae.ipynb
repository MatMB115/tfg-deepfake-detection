# %% [markdown]
# # Retreinar o GenConViT com Wild Deepfake
# Retreinar o modelo com o dataset wild deepfake utilizando os checkpoint fornecidos.
# ![genconvit_architecture](https://github.com/MatMB115/GenConViT_LIPs/blob/main/img/genconvit.png?raw=true)

# %%
# !git clone https://github.com/MatMB115/GenConViT_LIPs
# Out:
# fatal: destination path 'GenConViT_LIPs' already exists and is not an empty directory.

# %%
# !pip install -r GenConViT_LIPs/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 16.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 81.1 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.0/510.0 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 76.4 MB/s eta 0:00:00:00:010:01
# ...
#   Created wheel for dlib: filename=dlib-19.24.6-cp310-cp310-linux_x86_64.whl size=3590662 sha256=cded9544151fbdc719240b1ee5f8bbb21b5e2c505d95a5662c509c42cc711041
#   Stored in directory: /root/.cache/pip/wheels/7c/1d/d1/e69ceb001441acedfa6156acda6c1856699e260ea1a9e6dcc4
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566163 sha256=96dd236455c5a4510b01734b02ca22e2429491bc317803c96338502709815dcb
# ...

# %%
cd GenConViT_LIPs
# Out:
# /kaggle/working/GenConViT_LIPs

# %%
ls
# Out:
# LICENSE      dataset/    model/            result/        train.py
# README.md    img/        prediction.py     result_all.py  weight/
# __init__.py  json_file/  requirements.txt  train/

# %% [markdown]
# # WildDeepfake

# %% [markdown]
# ## FIRST 5 EPOCH

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m vae -p /kaggle/input/genconvit/pytorch/vae/1/genconvit_vae_inference.pth -e 5 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.15 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /root/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
# ...

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m vae -p /kaggle/working/GenConViT_LIPs/weight/genconvit_vae_Sep_20_2024_05_23_17.pth -e 5 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.15 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /root/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
# ...

# %% [markdown]
# ## 10 EPOCH (draft was lost, so a just scan the weight path - files persist)
# > 10 epoch is not a good result. Probally, i need ajust to less epochs.

# %%
ls GenConViT_LIPs/weight/genconvit_vae_Sep_21_2024_16_45_52.*
# Out:
# GenConViT_LIPs/weight/genconvit_vae_Sep_21_2024_16_45_52.pkl
# GenConViT_LIPs/weight/genconvit_vae_Sep_21_2024_16_45_52.pth

# %% [markdown]
# ## 6 EPOCH

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m vae -p /kaggle/working/GenConViT_LIPs/weight/genconvit_vae_Sep_20_2024_05_23_17.pth -e 1 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.16 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# => loading checkpoint '/kaggle/working/GenConViT_LIPs/weight/genconvit_vae_Sep_20_2024_05_23_17.pth'
# ...

# %% [markdown]
# ## 8 EPOCH
# > I intend ajust the checkpoint of 5 epochs to 8 epochs and see the result.

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m vae -p /kaggle/working/GenConViT_LIPs/weight/genconvit_vae_Sep_20_2024_05_23_17.pth -e 3 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.16 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/GenConViT_LIPs/train.py", line 208, in <module>
#     main()
#   File "/kaggle/working/GenConViT_LIPs/train.py", line 202, in main
#     train_model(path, mod, epoch, pretrained_model_filename, test_model, batch_size)
#   File "/kaggle/working/GenConViT_LIPs/train.py", line 40, in train_model
#     dataloaders, dataset_sizes = load_data(dir_path, batch_size)
#   File "/kaggle/working/GenConViT_LIPs/dataset/loader.py", line 83, in load_data
#     image_datasets = {
#   File "/kaggle/working/GenConViT_LIPs/dataset/loader.py", line 84, in <dictcomp>
# ...

# %% [markdown]
# # DeepSpeak

# %% [markdown]
# ## 4 Epochs

# %%
# !python train.py -d /kaggle/input/deepspeak/split_data_train -m vae -p /kaggle/input/genconvit/pytorch/vae/1/genconvit_vae_inference.pth -e 4 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.17 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /root/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
# ...

# %%
# !python train.py -d /kaggle/input/deepspeak/split_data_train -m vae -p /kaggle/working/GenConViT_LIPs/weight/genconvit_vae_Oct_03_2024_09_11_51.pth -e 1 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.17 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /root/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
# ...

# %% [markdown]
# ## 8 Epochs

# %%
# !python train.py -d /kaggle/input/deepspeak/split_data_train -m vae -p /kaggle/working/GenConViT_LIPs/weight/genconvit_vae_Oct_03_2024_19_30_09.pth -e 3 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /root/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
# ...
