# %% [markdown]
# # Retreinar o GenConViT
# Retreinar o modelo com o dataset wild deepfake utilizando os checkpoint fornecidos.
# ![genconvit_architecture](https://github.com/MatMB115/GenConViT_LIPs/blob/main/img/genconvit.png?raw=true)

# %% [markdown]
# # WildDeepfake

# %%
# !git clone https://github.com/MatMB115/GenConViT_LIPs
# Out:
# Cloning into 'GenConViT_LIPs'...
# remote: Enumerating objects: 467, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 467 (delta 84), reused 75 (delta 26), pack-reused 312 (from 1)
# Receiving objects: 100% (467/467), 60.78 MiB | 14.01 MiB/s, done.
# Resolving deltas: 100% (213/213), done.

# %%
# !pip install -r GenConViT_LIPs/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 16.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 76.9 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.0/510.0 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 85.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Created wheel for dlib: filename=dlib-19.24.6-cp310-cp310-linux_x86_64.whl size=3590654 sha256=882a3524b593354a991c578614aa7878b8dec2a11a2800a9e6b3a6b22b7caf80
#   Stored in directory: /root/.cache/pip/wheels/7c/1d/d1/e69ceb001441acedfa6156acda6c1856699e260ea1a9e6dcc4
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566163 sha256=721dd621ca6be299086e602b618e0104836bf1d40bd247125078cee3de21fc54
# ...

# %%
cd GenConViT_LIPs/
# Out:
# /kaggle/working/GenConViT_LIPs

# %%
ls
# Out:
# LICENSE      dataset/    model/            result/        train.py
# README.md    img/        prediction.py     result_all.py  weight/
# __init__.py  json_file/  requirements.txt  train/

# %% [markdown]
# ## FIRST 5 EPOCH

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m ed -p /kaggle/input/genconvit_ed/pytorch/ed/1/genconvit_ed_inference.pth -e 4 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.15 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# => loading checkpoint '/kaggle/input/genconvit_ed/pytorch/ed/1/genconvit_ed_inference.pth'
# ...

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m ed -p /kaggle/working/GenConViT_LIPs/weight/genconvit_ed_Sep_20_2024_06_48_04.pth -e 1 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.15 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# ## 8 EPOCH

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m ed -p /kaggle/working/GenConViT_LIPs/weight/genconvit_ed_Sep_20_2024_23_21_51.pth -e 3
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.16 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# ## 10 EPOCH

# %%
# !python train.py -d /kaggle/input/wild-deepfake -m ed -p /kaggle/working/GenConViT_LIPs/weight/genconvit_ed_Sep_24_2024_13_48_47.pth -e 2
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.16 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# # DeepSpeak

# %% [markdown]
# ## 4 Epochs

# %%
# !python train.py -d /kaggle/input/deepspeak/split_data_train -m ed -p /kaggle/input/genconvit_ed/pytorch/ed/1/genconvit_ed_inference.pth -e 4 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.17 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# ## 5 Epochs

# %%
# !python train.py -d /kaggle/input/deepspeak/split_data_train -m ed -p /kaggle/working/GenConViT_LIPs/weight/genconvit_ed_Oct_03_2024_03_04_24.pth -e 1 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.17 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# ## 8 Epochs

# %%
# !python train.py -d /kaggle/input/deepspeak/split_data_train -m ed -p /kaggle/working/GenConViT_LIPs/weight/genconvit_ed_Oct_03_2024_05_28_08.pth -e 3 -t y
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.14). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading data...
# Done.
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
